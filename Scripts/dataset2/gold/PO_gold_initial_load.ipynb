# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
df=spark.sql("""
SELECT *
FROM silver.production_orders
WHERE Nid not LIKE '%WO%'
""")
# Out:
# StatementMeta(, bbb5c5b5-a977-419e-947e-36aca0f98f42, 3, Finished, Available, Finished, False)

# %%
df.write.mode("overwrite").saveAsTable("gold.production_orders")
# Out:
# StatementMeta(, bbb5c5b5-a977-419e-947e-36aca0f98f42, 4, Finished, Available, Finished, False)
