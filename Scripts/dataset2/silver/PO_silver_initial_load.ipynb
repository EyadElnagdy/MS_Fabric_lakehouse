# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
df=spark.sql("""
SELECT *
FROM bronze.production_orders
WHERE valid_to is Null
""")
# Out:
# StatementMeta(, bb9a9be5-3398-4270-890a-a6276cdd0d82, 3, Finished, Available, Finished, False)

# %%
df.write.mode("overwrite").saveAsTable("silver.production_orders")
# Out:
# StatementMeta(, bb9a9be5-3398-4270-890a-a6276cdd0d82, 5, Finished, Available, Finished, False)
