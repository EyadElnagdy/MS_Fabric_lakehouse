# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
df=spark.sql("select CreatedOn from bronze.production_confirmation order by cast(CreatedOn as TIMESTAMP) desc limit 1")
max_date=str(df.first()[0])
spark.sql(f"UPDATE metadata.watermark set last_date='{max_date}' where tablename='bronze.production_confirmation'")
# Out:
# StatementMeta(, f267143c-2252-428e-8e60-c13bb747561c, 3, Finished, Available, Finished, False)
# DataFrame[num_affected_rows: bigint]
