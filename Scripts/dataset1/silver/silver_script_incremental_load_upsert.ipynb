# %%
spark.sql("""
MERGE INTO silver.production_confirmation AS t
USING bronze.production_confirmation AS s
ON t.id = s.id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *
""")
# Out:
# StatementMeta(, 6cf2df08-b94f-42f1-987b-53533ddcbf94, 3, Finished, Available, Finished, False)
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]
